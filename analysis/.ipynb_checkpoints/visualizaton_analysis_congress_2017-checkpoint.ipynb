# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import bz2
import json
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Members of the intersection of both the 115th and 116th US Congress
# All of these members where there during the whole 2016-2020 period (both 115th & 116th congress)
congress = pd.read_csv("/content/drive/MyDrive/ADA/congress_115_116.csv")

# %%
congress.head()
# Out:
#    Unnamed: 0 fec_candidate_id          speaker  ... date_of_birth gender state
# 0           0        H4LA05221    ralph abraham  ...    1954-09-16      M    LA
# 1           1        H4NC12100       alma adams  ...    1946-05-27      F    NC
# 2           2        H6AL04098  robert aderholt  ...    1965-07-22      M    AL
# 3           3        H2CA31125     pete aguilar  ...    1979-06-19      M    CA
# 4           4        H2GA12121       rick allen  ...    1951-11-07      M    GA
#
# [5 rows x 10 columns]

# %%
# %%time 
# link to the Drive repo + the year of the newpapers quotes
path_to_file = '/content/drive/MyDrive/ADA/quotes-2017-congress-speakers.json.bz2'
# here the data is in the ADA folder placed at the root of your Drive

quotes_2017_congress = []
with bz2.open(path_to_file, 'rb') as s_file:
    for i, sample in enumerate(s_file):
      quote = json.loads(sample)
      quotes_2017_congress.append(quote)
# Out:
# CPU times: user 31.9 s, sys: 951 ms, total: 32.8 s
# Wall time: 32.9 s

# %%
# Transforming the array of quotes in a pandas DataFrame
df_2017_congress = pd.DataFrame(quotes_2017_congress)
df_2017_congress.head()
# Out:
#              quoteID  ... phase
# 0  2017-10-31-000480  ...     E
# 1  2017-10-31-000757  ...     E
# 2  2017-07-26-084102  ...     E
# 3  2017-06-15-000974  ...     E
# 4  2017-07-28-001488  ...     E
#
# [5 rows x 9 columns]

# %%
# Counting the number of quotes by each member of the congress
df_2017_congress["speaker"].str.lower().value_counts()
# Out:
# mitch mcconnell     9783
# nancy pelosi        9489
# lindsey graham      9191
# elizabeth warren    5938
# marco rubio         5538
#                     ...
# tim k                  1
# amy k                  1
# z chen                 1
# ty murray              1
# d blum                 1
# Name: speaker, Length: 423, dtype: int64

# %%
# %%time
# Distribution of the number(#) of speakers in function of the # of quotes

ax11 = sns.histplot(data = df_2017_congress["speaker"].str.lower().value_counts(), bins=100)
ax11.set_title('Distribution of the number of speakers in function of the number of quotations (in 2017)')
ax11.set_ylabel('# Speaker(s)')
ax11.set_xlabel('Quotation(s)')
plt.show()
# Out:
# CPU times: user 814 ms, sys: 15.9 ms, total: 830 ms
# Wall time: 836 ms

# %%
# Merge congress_dataset and quotes_dataset to obtain additional features on the speaker
df_2017_congress["speaker"] = df_2017_congress["speaker"].str.lower()
df_2017_congress_merged = pd.merge(df_2017_congress, congress[["speaker", "party", "gender", "date_of_birth", 'state']], on=["speaker"], how='left')
df_2017_congress_merged.head()
# Out:
#              quoteID  ... state
# 0  2017-10-31-000480  ...    PA
# 1  2017-10-31-000757  ...    GA
# 2  2017-07-26-084102  ...    SC
# 3  2017-06-15-000974  ...    CA
# 4  2017-07-28-001488  ...    KY
#
# [5 rows x 13 columns]

# %%
# Number of quotes for this dataset
quotes_number_2017 = df_2017_congress_merged.shape[0]
print(f' Total number of quotes for congress dataset 2017: {quotes_number_2017}')
# Out:
#  Total number of quotes for congress dataset 2017: 313112

# %%
#-------------------Political party------------------------

df_party = df_2017_congress_merged['party'].value_counts().to_frame()
sns.set(rc={'figure.figsize':(11.7,8.27)})
ax2 = df_party.plot(kind='bar', rot=0, legend = False)
ax2.set_title("Number of quotes per party in 2017")
ax2.set_ylabel('# Quotes')
ax2.set_xlabel('Party')
plt.show()
df_party
# Out:
#      party
# R   169759
# D   138372
# ID    1884

# %%
#-----------------Gender-----------------

df_gender = df_2017_congress_merged['gender'].value_counts().to_frame()
sns.set(rc={'figure.figsize':(11.7,8.27)})
ax3 = df_gender.plot(kind='bar', rot=0, legend = False)
ax3.set_title('The number of per gender in 2017')
ax3.set_ylabel('# Quotes')
ax3.set_xlabel('Gender')
plt.show()
df_gender
# Out:
#    gender
# M  246449
# F   63566

# %%
#-----------------Age-----------------

df_2017_congress_merged['year_of_birth'] = pd.DatetimeIndex(df_2017_congress_merged['date_of_birth']).year.astype('Int64')
df_2017_congress_merged['age'] = (2017 - df_2017_congress_merged['year_of_birth']).astype('Int64')
sns.set(rc={'figure.figsize':(11.7,8.27)})
ax3 = sns.histplot(data = df_2017_congress_merged['age'], bins=20)
ax3.set_title("Distribution of the speaker's age in 2017")
ax3.set_ylabel('# Quotes')
ax3.set_xlabel('Age')
plt.show()

df_2017_congress_merged.describe().loc[['mean', '50%', 'min', 'max'],['age']]
# Out:
#             age
# mean  60.727758
# 50%   62.000000
# min   33.000000
# max   84.000000

# %%
#--------------------State-----------------------
# Heatmap of occurences of state origin of speaker 
#!pip install geopandas #to run once
import geopandas as gpd
from geopandas import GeoDataFrame
states_map = gpd.read_file("/content/drive/MyDrive/map/cb_2018_us_state_20m.shp")

fig, ax = plt.subplots(1, figsize=(30, 20))
df_state = df_2017_congress_merged['state'].value_counts().to_frame()
merged = df_state.merge(states_map, left_index=True, right_on='STUSPS')
merged = GeoDataFrame(merged)
merged.apply(lambda x: ax.annotate(s=x.STUSPS, xy=x.geometry.centroid.coords[0], ha='center', fontsize=14),axis=1);
merged.plot(column="state", cmap="Reds", ax=ax, linewidth=0.4, edgecolor=".4", legend=True, legend_kwds={'label': "# number of quotes retrieved speaker's state", 'orientation': "vertical"})
_ = ax.set_xlim([-170, -64])
_ = ax.set_ylim([22, 75])

# %%
ax2 = df_state.plot(kind='bar', rot=0, legend = False)
ax2.set_title("Distribution of the number of quotes per speaker's state")
ax2.set_ylabel('# Quotes')
ax2.set_xlabel('US state')
plt.show()

# %%
# Number of quotes containing the string "climate change"

num_quotes_climate_change = np.count_nonzero(df_2017_congress_merged['quotation'].str.count('climate change'), axis=0)
print(f'Number of quotes containing the string "climate change": {num_quotes_climate_change}')
# Out:
# Number of quotes containing the string "climate change": 639

# %%
# Number of quotes containing the string 'Paris agreement'

num_quotes_paris = np.count_nonzero(df_2017_congress_merged['quotation'].str.count('Paris agreement'), axis=0)
print(f'Number of quotes containing the string "Paris agreement": {num_quotes_paris}')
# Out:
# Number of quotes containing the string "Paris agreement": 33

# %%
# Number of quotes containing the string "health insurances"

num_quotes_health_insurance = np.count_nonzero(df_2017_congress_merged['quotation'].str.count('health insurance'), axis=0)
print(f'Number of quotes containing the string "health insurances": {num_quotes_health_insurance}')
# Out:
# Number of quotes containing the string "health insurances": 1291
